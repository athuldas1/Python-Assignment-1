# %%
"""1. String Concatenation:
Write a Python program that takes two strings i.e string 1 “Hello ”, string 2 get name as
input from the user and concatenates them together. Display the concatenated string as
the output. """
# Out:
# '1. String Concatenation: \nWrite a Python program that takes two strings i.e string 1 “Hello ”, string 2 get name as \ninput from the user and concatenates them together. Display the concatenated string as \nthe output. '

# %%
str1="Hello"
str2=input("Enter your name:")
result=str1 + " "+ str2
print(result)
# Out:
# Enter your name:Zara
# Hello Zara

# %%
#here we use concatenation to (+) joining two or more strings together

# %%
"""Now concatenate string 3 “, welcome to Python programming” to the existing string and
display the output string."""

# %%
str3="welcome to Python programming"
print(result + "," + str3)
# Out:
# Hello Zara,welcome to Python programming

# %%
#existing string and adding another string to its end

# %%
#2. String Slicing and Indexing:
#a. Print the first character of the string.

# %%
str1 = "Hello "
name = input("Enter your Name: ")

result = str1 + name

str3 = ", welcome to Python programming"

result = result + str3

print(result)
# Out:
# Enter your Name: zara
# Hello zara, welcome to Python programming

# %%
print(result[0])
# Out:
# H

# %%
#b. Print the last character of the string.
print(result[-1])
# Out:
# g

# %%
#c. Print the first 5 characters of the string.
#[:5] means start from the beginning and take characters up to position 5, but don't include position 5.
print(result[:5])
# Out:
# Hello

# %%
#d. Print the last 11 characters of the string.
print(result[-11:])
# Out:
# programming

# %%
#e. Print the string in reverse.
print(result[::-1])
# Out:
# gnimmargorp nohtyP ot emoclew ,araz olleH

# %%
#here -1 tell the code to move backward

# %%
#f. Use slicing and print the word “Python” from the existing string.
print(result[22:29])
# Out:
#  Python

# %%
#3. String Methods:
"""Write a Python program that takes a string, strM = “Python beginner tutorial” and
perform the following tasks: """
strM = "Python beginner tutorial"
print(strM)
# Out:
# Python beginner tutorial

# %%
#a. Convert the sentence to uppercase.
print(strM.upper())
# Out:
# PYTHON BEGINNER TUTORIAL

# %%
#b. Convert the sentence to lowercase.
print(strM.lower())
# Out:
# python beginner tutorial

# %%
#c. Use Capitalize and return the sentence to the original input form.
#makes the first character uppercase and converts the remaining characters to lowercase.
print(strM.capitalize())
# Out:
# Python beginner tutorial

# %%
#d. Count the total number of occurrences of character ‘t’  in the string.
print(strM.count("t"))
# Out:
# 3

# %%
"""e. Replace all occurrences of “Python” with “Machine Learning”  in the input string
strM = “Python beginner tutorial” """
print(strM.replace("Python", "Machine Learning"))
# Out:
# Machine Learning beginner tutorial

# %%
#Create 1st tuple with values -> (10, 20, 30), 2nd tuple with values -> (40, 50, 60):
t1 = (10, 20, 30)
t2 = (40, 50, 60)
#a. Concatenate the two tuples and store it in “t_combine”
# "+" icon is used to join two tuple
t_combine= t1 + t2
print(t_combine)
# Out:
# (10, 20, 30, 40, 50, 60)

# %%
#b. Repeat the elements of “t_combine” 3 times
print(t_combine * 3)
# Out:
# (10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60)

# %%
#c. Access the 3rd element from “t_combine”
print(t_combine[2])
# Out:
# 30

# %%
#d. Access the first three elements from “t_combine”
print(t_combine[:3])
# Out:
# (10, 20, 30)

# %%
#e. Access the last three elements from “t_combine”
print(t_combine[-3:])
# Out:
# (40, 50, 60)
